# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

import ollama
ollama_client = ollama

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, ollama_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, you can still join the course, but keep in mind that if you want to receive a certificate, you need to submit your project while the submissions are still being accepted.'
